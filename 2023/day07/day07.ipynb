# %%
from importlib import reload
import day07
reload(day07)
# Out:
# <module 'day07' from '/Users/olit/git_tree/advent-of-code/2023/day07/day07.py'>

# %%
day07.solve_p1('test_input07.txt')
# Out:
# 6440

# %%
day07.solve_p1('input07.txt')
# Out:
# 250602641

# %%
day07.solve_p2('test_input07.txt')
# Out:
# 5905

# %%
day07.solve_p2('input07.txt')
# Out:
# 251037509

# %%
day07.score_hands_p2(day07.parse_data(day07.read_data('input07.txt')))
# Out:
# [(1, 153699, '25863', 725, '25863'),
#  (2, 154182, '25T46', 95, '25T46'),
#  (3, 161881, '27859', 72, '27859'),
#  (4, 162021, '278A5', 395, '278A5'),
#  (5, 174419, '2T953', 933, '2T953'),
#  (6, 182381, '2Q86K', 693, '2Q86K'),
#  (7, 182634, '2Q96T', 398, '2Q96T'),
#  (8, 189811, '2A573', 741, '2A573'),
#  (9, 205964, '3248Q', 235, '3248Q'),
#  (10, 208468, '32A54', 746, '32A54'),
#  (11, 214762, '346AT', 426, '346AT'),
#  (12, 216215, '34Q97', 229, '34Q97'),
#  (13, 224681, '36KT9', 809, '36KT9'),
#  (14, 234189, '392QK', 679, '392QK'),
#  (15, 237122, '39A42', 244, '39A42'),
#  (16, 246421, '3Q295', 630, '3Q295'),
#  (17, 254604, '3A28Q', 779, '3A28Q'),
#  (18, 274086, '42AT6', 475, '42AT6'),
#  (19, 285325, '45T8K', 140, '45T8K'),
#  (20, 296685, '486AK', 713, '486AK'),
#  (21, 304860, '4T6KQ', 613, '4T6KQ'),
#  (22, 312888, '4Q638', 930, '4Q638'),
#  (23, 322904, '4AK58', 773, '4AK58'),
#  (24, 322968, '4AK98', 794, '4AK98'),
#  (25, 339060, '52Q74', 518, '52Q74'),
# ...
