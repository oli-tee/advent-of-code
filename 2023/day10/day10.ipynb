# %%
from importlib import reload
import day10
reload(day10)
# Out:
# <module 'day10' from '/Users/olit/git_tree/advent-of-code/2023/day10/day10.py'>

# %%
data = day10.read_data("test_input10_1.txt")

# %%
data = day10.read_data("test_input10_1.txt")
graph = day10.parse_graph(data)

# %%
day10.solve_p1("test_input10_1.txt", verbose=True)
# Out:
# .....
# .S-7.
# .|.|.
# .L-J.
# .....
# 4

# %%
day10.solve_p1("test_input10_2.txt", verbose=True)
# Out:
# ..F7.
# .FJ|.
# SJ.L7
# |F--J
# LJ...
# 8

# %%
day10.solve_p1("input10.txt", verbose=True)
# Out:
# ............................................................................................................................................
# ............................................................................................................................................
# ............................................................................................................................................
# ............................................................................................................................................
# ........................................F7..................................................................................................
# ........................................||F7.F7...F7...................................F7...................................................
# ...

# %% [markdown]
# # part 2

# %%
day10.solve_p2('test_input_p2_1.txt')
# Out:
# ...........
# .╔╧╧╧╧╧╧╧╗.
# .╢╔╧╧╧╧╧╗╢.
# .╢╢.....╢╢.
# .╢╢.....╢╢.
# .╢╚╧╗.╔╧╝╢.
# .╢OO╢.╢OO╢.
# .╚╧╧╝.╚╧╧╝.
# ...........
# 4

# %%
day10.solve_p2('test_input_p2_2.txt')
# Out:
# .╔╗╔╗╔╗╔╗╔╗╔╗╔╗╔╧╧╧╗
# .╢╚╝╢╢╢╢╢╢╢╢╢╢╢╢╔╧╧╝
# .╚╧╗╚╝╚╝╢╢╢╢╢╢╚╝╚╧╗.
# ╔╧╧╝╔╧╧╗╢╢╚╝╚╝O╔╗╔╝.
# ╚╧╧╧╝╔╧╝╚╝OOOO╔╝╚╝..
# ...╔╧╝╔╧╧╧╗OOO╚╗....
# ..╔╝╔╗╚╗╔╧╝╔╗OO╚╧╧╧╗
# ..╚╧╝╚╗╢╢╔╗╢╚╗╔╧╗╔╗╢
# .....╔╝╢╢╢╢╢╔╝╚╗╢╢╚╝
# .....╚╧╝╚╝╚╝╚╧╧╝╚╝..
# 10

# %%
day10.solve_p2('input10.txt')
# Out:
# ............................................................................................................................................
# ............................................................................................................................................
# ............................................................................................................................................
# ............................................................................................................................................
# ........................................╔╗..................................................................................................
# ........................................╢╢╔╗.╔╗...╔╗...................................╔╗...................................................
# ...
