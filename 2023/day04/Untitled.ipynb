# %%
from importlib import reload
import day04
import numpy as np
import re
reload(day04)
# Out:
# <module 'day04' from '/Users/olit/git_tree/advent-of-code/2023/day04/day04.py'>

# %%
s = 'Card   1:  9 39 27 89 87 29 54 19 43 45 |  9 80 29 20 54 58 78 '

# %%
day04.get_score_for_row(s)
# Out:
# 4

# %%
day04.solve_p1(day04.read_data('test_input04.txt'))
# Out:
# [8, 2, 2, 1, 0, 0]
# 13

# %%
day04.solve_p1(day04.read_data('input04.txt'))
# Out:
# [512, 512, 8, 512, 512, 512, 2, 4, 4, 8, 512, 8, 256, 32, 32, 64, 2, 16, 4, 0, 0, 1, 0, 4, 256, 128, 1, 512, 0, 256, 1, 512, 512, 0, 32, 512, 64, 256, 2, 128, 2, 0, 1, 0, 2, 2, 0, 0, 4, 0, 4, 128, 512, 32, 1, 2, 0, 16, 2, 2, 0, 0, 0, 512, 8, 2, 512, 256, 64, 0, 8, 32, 0, 4, 0, 1, 1, 0, 512, 512, 8, 128, 512, 8, 64, 64, 512, 512, 4, 0, 16, 0, 0, 1, 2, 1, 0, 0, 1, 0, 512, 0, 512, 32, 0, 512, 8, 512, 512, 512, 512, 2, 256, 1, 8, 16, 0, 8, 0, 0, 2, 1, 0, 512, 512, 512, 512, 512, 512, 512, 32, 16, 32, 4, 64, 32, 256, 16, 16, 1, 16, 2, 0, 1, 2, 1, 0, 256, 128, 8, 512, 1, 512, 64, 32, 1, 16, 0, 0, 4, 2, 1, 0, 64, 4, 64, 128, 512, 512, 512, 2, 512, 2, 256, 128, 256, 8, 0, 2, 2, 8, 0, 0, 1, 0, 512, 0, 512, 128, 2, 32, 512, 512, 512, 128, 8, 16, 8, 8, 8, 0, 2, 0, 0]
# 27059

# %%
day04.solve_p2(day04.read_data('test_input04.txt'))
# Out:
# [ 1.  2.  4.  8. 14.  1.]
# 30.0

# %%
day04.solve_p2(day04.read_data('input04.txt'))
# Out:
# [1.000000e+00 2.000000e+00 4.000000e+00 8.000000e+00 1.600000e+01
#  3.200000e+01 6.400000e+01 1.240000e+02 2.480000e+02 4.320000e+02
#  8.640000e+02 1.603000e+03 2.956000e+03 5.912000e+03 1.138400e+04
#  2.275200e+04 4.386900e+04 8.773800e+04 1.754760e+05 3.070830e+05
#  3.011710e+05 2.889230e+05 3.994140e+05 1.000000e+00 2.000000e+00
#  4.000000e+00 8.000000e+00 1.500000e+01 2.200000e+01 2.200000e+01
#  4.400000e+01 8.800000e+01 1.320000e+02 2.640000e+02 2.580000e+02
#  5.160000e+02 1.032000e+03 2.064000e+03 4.113000e+03 8.204000e+03
#  1.640800e+04 2.844500e+04 2.835700e+04 4.017400e+04 1.078500e+04
#  2.157000e+04 4.262400e+04 2.977500e+04 1.000000e+00 2.000000e+00
#  2.000000e+00 4.000000e+00 7.000000e+00 1.400000e+01 2.600000e+01
#  5.200000e+01 7.800000e+01 7.800000e+01 1.040000e+02 2.080000e+02
#  3.980000e+02 2.940000e+02 8.600000e+01 1.000000e+00 2.000000e+00
#  4.000000e+00 8.000000e+00 1.600000e+01 2.800000e+01 5.400000e+01
# ...
