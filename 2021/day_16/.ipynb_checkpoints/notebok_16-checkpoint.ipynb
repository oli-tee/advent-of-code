# %%
from importlib import reload
import module16
reload(module16)
from collections import Counter
import numpy as np

# %%
module16.read_data('input_16.txt')
# Out:
# '...'

# %%
module16.solve1(
    module16.read_data('input_16.txt'),
    verbose=False
)
# Out:
# 923

# %%
module16.solve2(module16.read_data('input_16.txt'), verbose=False)
# Out:
# 258888628940

# %%
module16.solve1(
    module16.read_data('input_16.txt'),
    verbose=True
)
# Out:
# sub-packets defined by length: 5380
# ('0011001001100110', 1, 54)
# sub-packet: 0011001001100110, version 1
# ('10100110000000001011011010000000001011010000111000100001110001001110001111', 17, 0)
# sub-packet: 10100110000000001011011010000000001011010000111000100001110001001110001111, version 17
# ('0111001011110100111101100101001', 3, 478873)
# sub-packet: 0111001011110100111101100101001, version 3
# ('01100110000000001010110011111111000000101111010000000001010110011101001010111001011011011101111100101101', 19, 4033)
# sub-packet: 01100110000000001010110011111111000000101111010000000001010110011101001010111001011011011101111100101101, version 19
# ('01010010111110101011011110110101101101010', 2, 128379578)
# sub-packet: 01010010111110101011011110110101101101010, version 2
# ('010001100000000011111100110010101010110011101010100111001110000011', 17, 6546540)
# sub-packet: 010001100000000011111100110010101010110011101010100111001110000011, version 17
# ...

# %%
module16.solve2(module16.read_data('input_16.txt'), True)
# Out:
# sub-packets defined by length: 5380
# ('0011001001100110', 1, 54)
# sub-packet: 0011001001100110, version 1
# ('10100110000000001011011010000000001011010000111000100001110001001110001111', 17, 0)
# sub-packet: 10100110000000001011011010000000001011010000111000100001110001001110001111, version 17
# ('0111001011110100111101100101001', 3, 478873)
# sub-packet: 0111001011110100111101100101001, version 3
# ('01100110000000001010110011111111000000101111010000000001010110011101001010111001011011011101111100101101', 19, 4033)
# sub-packet: 01100110000000001010110011111111000000101111010000000001010110011101001010111001011011011101111100101101, version 19
# ('01010010111110101011011110110101101101010', 2, 128379578)
# sub-packet: 01010010111110101011011110110101101101010, version 2
# ('010001100000000011111100110010101010110011101010100111001110000011', 17, 6546540)
# sub-packet: 010001100000000011111100110010101010110011101010100111001110000011, version 17
# ...
