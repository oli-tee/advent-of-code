# %%
import module_03
from importlib import reload
reload(module_03)
# Out:
# all tests passed
# 56
# <module 'module_03' from '/Users/oli/git_tree/datascience/advent/2021/day_03/module_03.py'>

# %%
data = module_03.read_data('input_03.txt')
module_03.solve(data)
# Out:
# 1082324

# %%
input = [
        '00100',
        '11110',
        '10110',
        '10111',
        '10101',
        '01111',
        '00111',
        '11100',
        '10000',
        '11001',
        '00010',
        '01010',
    ]

# %%
module_03.get_oxygen(input)
# Out:
# ['00100', '11110', '10110', '10111', '10101', '01111', '00111', '11100', '10000', '11001', '00010', '01010']
# ['11110', '10110', '10111', '10101', '11100', '10000', '11001']
# ['10110', '10111', '10101', '10000']
# ['10110', '10111', '10101']
# ['10110', '10111']
# 23

# %%
module_03.get_co2(input)
# Out:
# ['00100', '11110', '10110', '10111', '10101', '01111', '00111', '11100', '10000', '11001', '00010', '01010']
# ['00100', '01111', '00111', '00010', '01010']
# ['01111', '01010']
# 10

# %%
module_03.solve2(data)
# Out:
# ['101111101000', '110110011100', '010111111000', '010101000001', '011000000001', '100001111001', '000000001010', '010110111001', '111000011000', '001101010111', '010101110100', '100100010111', '001100010100', '010110010000', '011101001010', '100101111110', '110010100011', '100110000011', '100100000100', '110000000011', '100101000000', '111011010001', '010000101111', '001100001100', '110010101001', '001000001111', '111100001000', '100011111110', '101110011111', '100001001010', '011110111100', '101010000000', '000101000110', '101000000111', '111010000001', '111111101101', '011111100010', '000100111111', '001000111000', '001101100100', '101100010111', '100011101010', '110100101001', '110011001010', '110100001110', '011110011011', '001111001110', '100110011011', '101011011110', '110101000001', '011010010001', '110010111100', '100101010001', '100101010011', '111100110011', '010111000100', '000100000101', '101000010011', '101110111110', '111101001101', '011110011110', '000101001100', '0001
# ...
