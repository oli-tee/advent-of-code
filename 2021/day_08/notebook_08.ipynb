# %%
from importlib import reload
import module08
reload(module08)
from typing import List
from collections import Counter

# %% [raw]
# module08.read_data('input_08.txt')

# %%
x = module08.read_data('test_input.txt')[0][1]

# %%
module08.solve1(module08.read_data('input_08.txt'))
# Out:
# 321

# %%
module08.solve2(module08.read_data('input_08.txt'))
# Out:
# ['d', 'b', 'a', 'f', 'e', 'c', 'g']
# ['b', 'g', 'e', 'd', 'c', 'f', 'a']
# ['f', 'b', 'd', 'e', 'g', 'c', 'a']
# ['e', 'b', 'f', 'd', 'c', 'a', 'g']
# ['g', 'b', 'f', 'a', 'c', 'e', 'd']
# ['b', 'a', 'd', 'c', 'g', 'e', 'f']
# ['e', 'f', 'c', 'g', 'b', 'a', 'd']
# ['g', 'a', 'b', 'e', 'c', 'f', 'd']
# ['c', 'f', 'e', 'a', 'd', 'b', 'g']
# ['g', 'a', 'e', 'd', 'b', 'c', 'f']
# ['a', 'b', 'g', 'e', 'd', 'f', 'c']
# ['c', 'e', 'f', 'b', 'a', 'd', 'g']
# ['e', 'd', 'f', 'a', 'c', 'g', 'b']
# ['g', 'f', 'd', 'c', 'a', 'b', 'e']
# ['b', 'd', 'g', 'a', 'f', 'c', 'e']
# ['g', 'e', 'd', 'a', 'b', 'f', 'c']
# ['c', 'e', 'd', 'f', 'b', 'a', 'g']
# ['c', 'a', 'e', 'f', 'g', 'd', 'b']
# ['g', 'b', 'f', 'a', 'c', 'd', 'e']
# ['d', 'g', 'b', 'a', 'f', 'c', 'e']
# ['a', 'e', 'd', 'c', 'g', 'f', 'b']
# ['d', 'b', 'a', 'f', 'c', 'g', 'e']
# ['d', 'c', 'a', 'e', 'g', 'f', 'b']
# ['c', 'e', 'a', 'g', 'b', 'f', 'd']
# ['e', 'd', 'f', 'g', 'b', 'c', 'a']
# ['b', 'f', 'a', 'e', 'c', 'g', 'd']
# ['f', 'd', 'e', 'c', 'g', 'a', 'b']
# ['a', 'g', 'd', 'c', 'e', 'f', 'b']
# ['e', 'b', 'f', 'd', 'g', 'c', 'a']
# ['b', 'e', 'f', 'g', 'c', 'a', 'd']
# ['d', 'a', 'e', 'b', 'f', 'c', 'g']
# ['d', 'f', 'a', 'g', 'e', 'c', 'b']
# ['b', 'a', 'e', 'g', 'd', 'f', 'c']
# ['f', 'e', 'd', 'g', 'c', 'b', 'a']
# ['f', 'd', 'a', 'c', 'b', 'e', 'g']
# ['b', 'e', 'd', 'a', 'g', 'f', 'c']
# ['g', 'f', 'd', 'c', 'e', 'b', 'a']
# ['d', 'a', 'b', 'f', 'g', 'c', 'e']
# ['e', 'c', 'f', 'd', 'a', 'b', 'g']
# ['d', 'f', 'g', 'c', 'e', 'b', 'a']
# ['b', 'c', 'g', 'e', 'f', 'a', 'd']
# ['c', 'f', 'g', 'd', 'b', 'a', 'e']
# ['f', 'e', 'c', 'b', 'a', 'g', 'd']
# ['a', 'd', 'f', 'c', 'g', 'b', 'e']
# ['d', 'g', 'b', 'e', 'a', 'c', 'f']
# ['b', 'c', 'd', 'g', 'a', 'f', 'e']
# ['e', 'd', 'f', 'a', 'c', 'g', 'b']
# ['e', 'd', 'c', 'b', 'a', 'f', 'g']
# ['a', 'd', 'b', 'g', 'e', 'f', 'c']
# ['f', 'b', 'c', 'g', 'e', 'a', 'd']
# ['d', 'g', 'a', 'e', 'b', 'f', 'c']
# ['b', 'a', 'g', 'c', 'f', 'd', 'e']
# ['g', 'd', 'f', 'c', 'a', 'e', 'b']
# ['f', 'c', 'a', 'e', 'd', 'g', 'b']
# ['f', 'g', 'e', 'a', 'd', 'b', 'c']
# ['e', 'a', 'c', 'f', 'g', 'b', 'd']
# ['c', 'a', 'b', 'd', 'e', 'f', 'g']
# ['e', 'a', 'c', 'd', 'g', 'f', 'b']
# ['c', 'g', 'a', 'e', 'f', 'd', 'b']
# ['g', 'a', 'f', 'c', 'e', 'd', 'b']
# ['f', 'b', 'c', 'a', 'd', 'e', 'g']
# ['f', 'a', 'c', 'b', 'd', 'g', 'e']
# ['f', 'e', 'd', 'a', 'g', 'c', 'b']
# ['f', 'd', 'e', 'g', 'c', 'b', 'a']
# ['a', 'g', 'd', 'c', 'f', 'b', 'e']
# ['b', 'g', 'e', 'd', 'c', 'a', 'f']
# ['f', 'c', 'e', 'a', 'b', 'g', 'd']
# ['f', 'a', 'e', 'd', 'c', 'g', 'b']
# ['b', 'e', 'f', 'g', 'c', 'd', 'a']
# ['f', 'e', 'd', 'g', 'b', 'a', 'c']
# ['b', 'f', 'd', 'g', 'e', 'a', 'c']
# ['e', 'b', 'd', 'g', 'a', 'c', 'f']
# ['c', 'b', 'f', 'e', 'a', 'd', 'g']
# ['b', 'e', 'g', 'f', 'd', 'a', 'c']
# ['g', 'b', 'f', 'e', 'd', 'a', 'c']
# ['f', 'a', 'g', 'b', 'c', 'e', 'd']
# ['b', 'c', 'g', 'd', 'f', 'e', 'a']
# ['b', 'a', 'c', 'f', 'd', 'g', 'e']
# ['e', 'a', 'c', 'f', 'g', 'b', 'd']
# ['g', 'd', 'b', 'f', 'e', 'c', 'a']
# ['a', 'g', 'c', 'f', 'b', 'd', 'e']
# ['d', 'c', 'g', 'e', 'b', 'a', 'f']
# ['c', 'g', 'a', 'd', 'b', 'e', 'f']
# ['a', 'e', 'f', 'c', 'g', 'b', 'd']
# ['g', 'c', 'd', 'a', 'f', 'b', 'e']
# ['e', 'g', 'b', 'd', 'a', 'f', 'c']
# ['e', 'g', 'a', 'b', 'c', 'f', 'd']
# ['f', 'c', 'e', 'b', 'a', 'g', 'd']
# ['d', 'b', 'e', 'a', 'f', 'g', 'c']
# ['e', 'g', 'f', 'c', 'd', 'b', 'a']
# ['g', 'f', 'a', 'd', 'b', 'c', 'e']
# ['b', 'e', 'g', 'd', 'f', 'a', 'c']
# ['f', 'c', 'b', 'e', 'd', 'a', 'g']
# ['a', 'g', 'd', 'f', 'c', 'b', 'e']
# ['b', 'd', 'g', 'c', 'a', 'f', 'e']
# ['e', 'f', 'g', 'c', 'b', 'a', 'd']
# ['f', 'd', 'g', 'b', 'a', 'c', 'e']
# ['e', 'c', 'd', 'g', 'a', 'f', 'b']
# ['b', 'f', 'e', 'd', 'g', 'a', 'c']
# ['d', 'g', 'a', 'b', 'f', 'c', 'e']
# ['e', 'a', 'b', 'c', 'd', 'f', 'g']
# ['d', 'c', 'g', 'a', 'b', 'e', 'f']
# ['f', 'e', 'g', 'b', 'd', 'a', 'c']
# ['e', 'c', 'f', 'a', 'b', 'g', 'd']
# ['c', 'a', 'd', 'b', 'f', 'e', 'g']
# ['a', 'b', 'f', 'd', 'e', 'g', 'c']
# ['c', 'g', 'e', 'f', 'b', 'a', 'd']
# ['e', 'b', 'f', 'd', 'c', 'a', 'g']
# ['e', 'f', 'd', 'b', 'c', 'a', 'g']
# ['e', 'a', 'g', 'f', 'd', 'c', 'b']
# ['b', 'e', 'c', 'f', 'd', 'g', 'a']
# ['d', 'f', 'b', 'e', 'g', 'a', 'c']
# ['a', 'b', 'f', 'c', 'g', 'e', 'd']
# ['e', 'g', 'b', 'a', 'f', 'd', 'c']
# ['b', 'a', 'f', 'e', 'd', 'g', 'c']
# ['f', 'd', 'b', 'a', 'g', 'e', 'c']
# ['d', 'g', 'f', 'c', 'b', 'e', 'a']
# ['g', 'e', 'a', 'f', 'd', 'c', 'b']
# ['a', 'e', 'b', 'g', 'd', 'f', 'c']
# ['b', 'd', 'g', 'e', 'a', 'f', 'c']
# ['b', 'f', 'g', 'a', 'e', 'd', 'c']
# ['c', 'f', 'd', 'e', 'a', 'b', 'g']
# ['d', 'b', 'g', 'c', 'a', 'f', 'e']
# ['d', 'g', 'b', 'f', 'e', 'a', 'c']
# ['d', 'b', 'c', 'a', 'f', 'e', 'g']
# ['f', 'c', 'g', 'e', 'b', 'd', 'a']
# ['a', 'b', 'd', 'c', 'g', 'e', 'f']
# ['a', 'c', 'b', 'd', 'g', 'e', 'f']
# ['e', 'g', 'f', 'd', 'a', 'b', 'c']
# ['f', 'g', 'd', 'e', 'a', 'b', 'c']
# ['e', 'f', 'g', 'b', 'c', 'd', 'a']
# ['g', 'f', 'c', 'b', 'd', 'e', 'a']
# ['a', 'd', 'g', 'f', 'c', 'e', 'b']
# ['f', 'g', 'd', 'e', 'c', 'b', 'a']
# ['f', 'b', 'c', 'a', 'e', 'g', 'd']
# ['a', 'g', 'c', 'f', 'b', 'e', 'd']
# ['d', 'b', 'e', 'g', 'a', 'c', 'f']
# ['c', 'b', 'a', 'g', 'e', 'd', 'f']
# ['e', 'f', 'a', 'd', 'g', 'b', 'c']
# ['c', 'd', 'g', 'a', 'f', 'b', 'e']
# ['b', 'a', 'f', 'd', 'c', 'g', 'e']
# ['c', 'b', 'd', 'f', 'a', 'e', 'g']
# ['b', 'd', 'a', 'e', 'f', 'c', 'g']
# ['f', 'd', 'a', 'c', 'g', 'b', 'e']
# ['e', 'a', 'c', 'b', 'f', 'd', 'g']
# ['c', 'e', 'a', 'd', 'b', 'g', 'f']
# ['d', 'f', 'a', 'b', 'g', 'e', 'c']
# ['e', 'f', 'c', 'g', 'b', 'a', 'd']
# ['a', 'g', 'd', 'e', 'c', 'f', 'b']
# ['a', 'f', 'b', 'd', 'g', 'c', 'e']
# ['b', 'g', 'd', 'e', 'c', 'a', 'f']
# ['c', 'f', 'g', 'a', 'b', 'e', 'd']
# ['b', 'g', 'e', 'c', 'd', 'f', 'a']
# ['a', 'b', 'g', 'e', 'c', 'f', 'd']
# ['b', 'a', 'd', 'g', 'f', 'c', 'e']
# ['b', 'a', 'e', 'c', 'd', 'f', 'g']
# ['a', 'f', 'd', 'c', 'b', 'e', 'g']
# ['e', 'd', 'c', 'a', 'f', 'g', 'b']
# ['c', 'g', 'f', 'b', 'a', 'd', 'e']
# ['d', 'e', 'f', 'c', 'b', 'a', 'g']
# ['c', 'e', 'g', 'f', 'd', 'a', 'b']
# ['d', 'e', 'c', 'a', 'g', 'b', 'f']
# ['d', 'c', 'e', 'f', 'a', 'g', 'b']
# ['g', 'e', 'a', 'b', 'f', 'd', 'c']
# ['a', 'c', 'b', 'g', 'd', 'e', 'f']
# ['a', 'g', 'f', 'e', 'c', 'd', 'b']
# ['a', 'g', 'd', 'e', 'b', 'f', 'c']
# ['d', 'b', 'f', 'c', 'a', 'g', 'e']
# ['e', 'd', 'f', 'g', 'a', 'b', 'c']
# ['a', 'b', 'c', 'g', 'd', 'e', 'f']
# ['d', 'f', 'e', 'g', 'c', 'b', 'a']
# ['d', 'g', 'b', 'f', 'a', 'c', 'e']
# ['g', 'd', 'f', 'e', 'b', 'c', 'a']
# ['c', 'g', 'f', 'd', 'e', 'b', 'a']
# ['c', 'b', 'g', 'f', 'a', 'd', 'e']
# ['d', 'g', 'e', 'b', 'f', 'a', 'c']
# ['b', 'e', 'f', 'g', 'c', 'd', 'a']
# ['e', 'd', 'f', 'b', 'a', 'c', 'g']
# ['b', 'c', 'g', 'f', 'd', 'e', 'a']
# ['d', 'e', 'a', 'b', 'f', 'c', 'g']
# ['g', 'b', 'a', 'd', 'e', 'c', 'f']
# ['c', 'e', 'b', 'g', 'd', 'f', 'a']
# ['d', 'b', 'f', 'c', 'g', 'a', 'e']
# ['e', 'g', 'a', 'c', 'f', 'b', 'd']
# ['e', 'f', 'd', 'g', 'b', 'a', 'c']
# ['g', 'a', 'f', 'b', 'c', 'd', 'e']
# ['b', 'g', 'f', 'e', 'd', 'c', 'a']
# ['b', 'd', 'c', 'a', 'g', 'f', 'e']
# ['a', 'e', 'g', 'd', 'c', 'b', 'f']
# ['e', 'd', 'b', 'g', 'a', 'c', 'f']
# ['e', 'c', 'g', 'b', 'f', 'd', 'a']
# ['g', 'a', 'b', 'f', 'd', 'c', 'e']
# ['f', 'd', 'a', 'c', 'b', 'e', 'g']
# ['f', 'e', 'd', 'b', 'a', 'c', 'g']
# ['e', 'g', 'b', 'd', 'c', 'f', 'a']
# ['d', 'b', 'a', 'c', 'g', 'f', 'e']
# ['f', 'a', 'd', 'b', 'c', 'g', 'e']
# ['a', 'g', 'd', 'f', 'c', 'e', 'b']
# ['b', 'e', 'g', 'c', 'd', 'a', 'f']
# ['c', 'f', 'b', 'd', 'a', 'g', 'e']
# 1028926

# %% [raw]
#     position 4: 4 times
#     position 1: 6 times
#     position 5: 9 times
#
#
#     position 0 & 2: 8 times
#     position 0 can be deduced from digits 7 (3 on) and 1 (2 on)
